# %% [markdown]
# # Idea

# %% [markdown]
# # My solution

# %%
class Solution: 
    def convert_to_zigzag(self, s:str, num_rows:int) -> str:
        return s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Tests

# %%
test_solution = Solution()

def test(inputs:dict, answer: str, t_number:int) -> None:
    print("---------------------")
    print(f"--Test-{t_number}--")
    output = test_solution.convert_to_zigzag(**inputs)
    print(f"expected: {answer}")
    print(f"actual:   {output}")
    assert output == answer
    print(f"Test {t_number} passes")
    print("---------------------")


print("---------------------")
# -----------------------
# From Prompt
# -----------------------

# Test 1
test({"s": "PAYPALISHIRING", "numRows": 3},
     "PAHNAPLSIIGYIR", 1)

# -----------------------
# Additional Edge Cases
# -----------------------

# Test 4 — single character and many rows
test({"s": "X", "numRows": 5},
     "X", 4)

print("---------------------")
print("All tests pass!")
print("---------------------")
# Out:
# ---------------------
# ---------------------
# --Test-1--
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      20 s = "barfoothefoobarman"
#      21 words = ["foo","bar"]
# ---> 22 test(s, words, [0, 9],1)
#      26 # -----------------------
#      27 # Edge Cases
#      28 # -----------------------
#
# Cell In[4], line 6, in test(input_s, input_words, answer, t_number)
#       4 print("---------------------")
#       5 print(f"--Test-{t_number}--")
# ----> 6 output = convert_to_zigzag(input_s, input_words)
#       7 print(f"expected: {answer}")
#       8 print(f"actual:   {output}")
#
# NameError: name 'convert_to_zigzag' is not defined

# %% [markdown]
# # Chat GPT's solution
